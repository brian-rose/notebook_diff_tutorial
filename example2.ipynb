# %% [markdown]
# # Example notebook for testing diff and merge tools
#
# Brian Rose
#
# brose@albany.edu

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Here's some descriptive text.
#
# Now with an equation!
#
# $$ y = \sin^2 x $$

# %%
X = np.linspace(0, 2*np.pi)
Y = np.sin(X)**2

# %%
plt.plot(X,Y)
